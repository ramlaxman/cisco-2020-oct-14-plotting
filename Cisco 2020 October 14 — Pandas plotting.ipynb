# %%
# %pylab inline
import pandas as pd
from pandas import Series, DataFrame
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
asdfasf  asdfa  asdfa  asdfaf
# Out:
#   File "<ipython-input-3-20c86d0d8d30>", line 1
#     asdfasf  asdfa  asdfa  asdfaf
#              ^
# SyntaxError: invalid syntax

# %%
s = Series([10, 20, 30, 40, 50, 40, 30, 40, 50])

# %%
s.plot.line()
# Out:
# <AxesSubplot:>

# %%
s.plot.line(color='red')
# Out:
# <AxesSubplot:>

# %%
s = Series([10, 20, 30, 40, 50, 40, 30, 40, 50],
          index='Jan Feb Mar Apr May Jun Jul Aug Sep'.split())

# %%
s.plot.line()
# Out:
# <AxesSubplot:>

# %%
s.plot.line(title='My amazing plot')
# Out:
# <AxesSubplot:title={'center':'My amazing plot'}>

# %%
help(s.plot.line)
# Out:
# Help on method line in module pandas.plotting._core:
#
# line(x=None, y=None, **kwargs) method of pandas.plotting._core.PlotAccessor instance
#     Plot Series or DataFrame as lines.
#
#     This function is useful to plot lines using DataFrame's values
#     as coordinates.
#
#     Parameters
#     ----------
#     x : label or position, optional
#         Allows plotting of one column versus another. If not specified,
#         the index of the DataFrame is used.
#     y : label or position, optional
#         Allows plotting of one column versus another. If not specified,
#         all numerical columns are used.
#     color : str, array_like, or dict, optional
#         The color for each of the DataFrame's columns. Possible values are:
#
#         - A single color string referred to by name, RGB or RGBA code,
#             for instance 'red' or '#a98d19'.
#
#         - A sequence of color strings referred to by name, RGB or RGBA
# ...

# %%
s.plot.bar()
# Out:
# <AxesSubplot:>

# %%
s.plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Exercise: Playing with plots
#
# 1. Create a series of 15 random integers from 0-100 (you can use `np.random.randint(0, 100, 15)`), with an index of the letters a-o.
# 2. Create a line plot from this data.
# 3. Create a bar plot from this data, but only for the indexes a-j.

# %%
s = Series(np.random.randint(0, 100, 15),
          index=list('abcdefghijklmno'))
s
# Out:
# a    22
# b    57
# c    81
# d    82
# e    54
# f    30
# g    13
# h    23
# i    47
# j    66
# k    23
# l    44
# m    95
# n    57
# o    12
# dtype: int64

# %%
s.plot.line()
# Out:
# <AxesSubplot:>

# %%
s['a':'j'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
s = Series([10, 20, 30, 40, 50, 40, 30, 40, 50])

# %%
s.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# pie plot

s.plot.pie()
# Out:
# <AxesSubplot:ylabel='None'>

# %%
s.sum()
# Out:
# 310

# %%
10/310
# Out:
# 0.03225806451612903

# %%
s.value_counts()
# Out:
# 40    3
# 30    2
# 50    2
# 10    1
# 20    1
# dtype: int64

# %%
s.value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='None'>

# %%
# John Tukey
# descriptive statistics

s.describe()
# Out:
# count     9.000000
# mean     34.444444
# std      13.333333
# min      10.000000
# 25%      30.000000
# 50%      40.000000
# 75%      40.000000
# max      50.000000
# dtype: float64

# %%
# box plot
# box-and-whiskers plot

s.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = DataFrame(np.random.randint(0, 100, [6,6]),
              columns=list('uvwxyz'),
              index=list('abcdef'))

df
# Out:
#     u   v   w   x   y   z
# a  34  15  33  79  31  41
# b  81  39  80  73  62  73
# c  11  29  81  74  94   2
# d  11  54  38   4  99  84
# e  44  38   3  33  35  43
# f   0  59  26  60  77  67

# %%
df['x'].mean()
# Out:
# 53.833333333333336

# %%
df['x'].describe()
# Out:
# count     6.000000
# mean     53.833333
# std      29.539239
# min       4.000000
# 25%      39.750000
# 50%      66.500000
# 75%      73.750000
# max      79.000000
# Name: x, dtype: float64

# %%
df['x'].plot.line()
# Out:
# <AxesSubplot:>

# %%
df.mean()
# Out:
# u    30.166667
# v    39.000000
# w    43.500000
# x    53.833333
# y    66.333333
# z    51.666667
# dtype: float64

# %%
df.plot.line()
# Out:
# <AxesSubplot:>

# %%
df[['v', 'x', 'z']].plot.line()
# Out:
# <AxesSubplot:>

# %%
df[['v', 'x', 'z']].plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Exercise: Taxi plotting
#
# 1. Extract `taxi.csv` from the zipfile at the link I gave.
# 2. Read in `taxi.csv` to a data frame; you only need to worry about three columns: `passenger_count`, `trip_distance`, and `total_amount`
# 3. Create a line plot for `passenger_count` for the first 100 rows in the data frame.
# 4. Create a line plot for both `trip_distance` and `total_amount` for the first 20 rows in the data frame.

# %%
df = pd.read_csv('taxi.csv',
                usecols=['passenger_count', 'trip_distance', 'total_amount'])
df.head()
# Out:
#    passenger_count  trip_distance  total_amount
# 0                1           1.63         17.80
# 1                1           0.46          8.30
# 2                1           0.87         11.00
# 3                1           2.13         17.16
# 4                1           1.40         10.30

# %%
df['passenger_count'][:100].plot.line()
# Out:
# <AxesSubplot:>

# %%
df[['passenger_count', 'trip_distance']][:20].plot.line()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv('taxi.csv')
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-06-02 11:19:29   2015-06-02 11:47:52                1
# 1         2  2015-06-02 11:19:30   2015-06-02 11:27:56                1
# 2         2  2015-06-02 11:19:31   2015-06-02 11:30:30                1
# 3         2  2015-06-02 11:19:31   2015-06-02 11:39:02                1
# 4         1  2015-06-02 11:19:32   2015-06-02 11:32:49                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.63        -73.954430        40.764141           1
# 1           0.46        -73.971443        40.758942           1
# 2           0.87        -73.978111        40.738434           1
# 3           2.13        -73.945892        40.773529           1
# 4           1.40        -73.979088        40.776772           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
df[['fare_amount','extra', 'mta_tax', 'tip_amount','tolls_amount','improvement_surcharge']][:10].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df[['fare_amount','extra', 'mta_tax', 'tip_amount','tolls_amount','improvement_surcharge']][:10].plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df[['fare_amount','extra', 'mta_tax', 'tip_amount','tolls_amount','improvement_surcharge']].plot.box()
# Out:
# <AxesSubplot:>

# %%
df[['passenger_count','total_amount', 'trip_distance']].plot.box()
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                        VendorID  passenger_count  trip_distance  \
# VendorID               1.000000         0.310755       0.025181
# passenger_count        0.310755         1.000000       0.014365
# trip_distance          0.025181         0.014365       1.000000
# pickup_longitude      -0.036464        -0.011933       0.018395
# pickup_latitude        0.036616         0.011985      -0.017465
# RateCodeID             0.002643        -0.006560       0.451383
# dropoff_longitude     -0.036305        -0.010666       0.014380
# dropoff_latitude       0.036246         0.010706      -0.013923
# payment_type          -0.011719         0.019185      -0.083705
# fare_amount            0.015924         0.008489       0.880674
# extra                 -0.020203        -0.020078       0.077046
# mta_tax                0.006241         0.008596      -0.166809
# tip_amount             0.004623        -0.014005       0.523592
# tolls_amount           0.006729         0.014839       0.592941
# ...

# %%
df.plot.scatter(x='trip_distance', y='total_amount')
# Out:
# <AxesSubplot:xlabel='trip_distance', ylabel='total_amount'>

# %% [markdown]
# # Exercise: Plotting and taxis
#
# 1. Create a scatter plot (as I did) between `trip_distance` and `total_amount`.  Make sure that you can see the correlation.
# 2. Create a scatter plot between `trip_distance` and `passenger_count`. Before running it, think — is there a correlation?  You can look at the number from `.corr()` afterwards.

# %%
df.plot.scatter(x='trip_distance', y='total_amount')
# Out:
# <AxesSubplot:xlabel='trip_distance', ylabel='total_amount'>

# %%
df.plot.scatter(x='trip_distance', y='passenger_count')
# Out:
# <AxesSubplot:xlabel='trip_distance', ylabel='passenger_count'>

# %%
df.plot.scatter(x='trip_distance', y='total_amount',
               c='passenger_count')
# Out:
# <AxesSubplot:xlabel='trip_distance', ylabel='total_amount'>

# %%
df.plot.scatter(x='trip_distance', y='total_amount',
               c='passenger_count', colormap='Accent')
# Out:
# <AxesSubplot:xlabel='trip_distance', ylabel='total_amount'>

# %%
df = df.query('total_amount <= 100')

# %%
df = df.query('trip_distance <= 30')

# %%
df.plot.scatter(x='trip_distance', y='total_amount',
               c='passenger_count', colormap='Accent')
# Out:
# <AxesSubplot:xlabel='trip_distance', ylabel='total_amount'>
