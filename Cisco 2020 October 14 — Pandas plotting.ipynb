# %%
# %pylab inline
import pandas as pd
from pandas import Series, DataFrame
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
asdfasf  asdfa  asdfa  asdfaf
# Out:
#   File "<ipython-input-3-20c86d0d8d30>", line 1
#     asdfasf  asdfa  asdfa  asdfaf
#              ^
# SyntaxError: invalid syntax

# %%
s = Series([10, 20, 30, 40, 50, 40, 30, 40, 50])

# %%
s.plot.line()
# Out:
# <AxesSubplot:>
